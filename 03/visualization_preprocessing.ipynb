# %% [markdown]
# # Domácí úkol č. 3 - 📈 Vizualizace ve strojovém učení od A do Z
#
# ## 📚 Data
# Pro tento úkol si studenti **zvolí vhodná data sami**. ☝️ Zvolená data by měla být veřejně dostupná a měla by simulovat nebo odpovídat nějaké reálné situaci (tzn. syntetická/vygenerovaná data neuvažujeme!). Data si vybírejte tak, abyste na nich byli schopni řešit klasifikační nebo regresní úlohu (tedy supervizované učení, přítomnost výstupní proměnné).
#
# **Pro odvážné:** Pokud se cítíte silní v kramflecích, můžete si zvolit i nesupervizovanou úlohu, např. shlukování.
#
# #### Tipy na data a řešení
# V souboru datasets_tips.md můžete najít tipy na různé veřejné weby s datasety.
#
# Inspiraci pro vypracování úkolu najdete v praktických ukázkách k přednáškám č. 8 a 9. Nicméně pouze zkopírovaný kód nebude hodnocen kladně.
#
# ☝️**Pozor!** Zkuste si zvolit trochu nápaditý dataset. Pokud si zvolíte dataset, který je často součástí tutoriálů (např. [Titanic dataset](https://www.tensorflow.org/datasets/catalog/titanic) nebo [Iris dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris)), pro zisk plného počtu bodů budete muset zřejmě vynaložit větší úsilí při jeho kreativní a neotřelé prezentaci.
#
# ## Zadání
# > ☝️ Používejte **markdown buňky**! Zdůvodňujte všechny důležité kroky, popisujte vizualizace a co je z nich možné pozorovat. Za nepřehledný domácí úkol nebudou uděleny body.
#
# Za řádné průběžné komentování a vizuální prezentaci postupu a výsledků lze získat až 10 bodů. Notebook odevzdávejte po spuštění (tzn. včetně output buněk) a zkrontrolujte si, že se komentáře korektně zobrazují ('rendered file' na GitLabu ve vašem prohlížeči).
#
# Úkol můžete vypracovávat jako **jednotlivci** nebo **ve skupině maximálně 3 spolužáků**. Postup pro hodnocení skupiny najdete na stránkách předmětu [zde](https://courses.fit.cvut.cz/BI-VIZ/homeworks/index.html#_podrobnosti-k-hodnocen%C3%AD-třet%C3%ADho-úkolu).
#
# ### Pokyny pro vypracování
#
# 🙏 Pokud je to možné, v každém bodě vaší práce **využijte vizualizace** a svá zjištění komentujte.
#
# **📖 Vaše úloha:**
# 1. Popište klasifikační/regresní úlohu, kterou v rámci domácího úkolu budete řešit.
# 2. Uveďte zdroj, odkud čerpáte data. ⛔️ Pozn.: Pokud pracujete s lokálně uloženým datasetem, odevzdejte jej spolu s vyřešeným Jupyter Notebookem prostřednictvím GitLabu. To aby s daty mohl pracovat i vyučující při opravě.
#
# **✨ Dataset:**
# V této části máte za úkol načíst zvolená data a pomocí vizualizace a popisných statistik se s nimi seznámit. Dále je nutné data vhodným způsobem předzpracovat, abyste je mohli použít pro trénování modelu.
# 1. Načtěte si zvolený dataset a importujte potřebné knihovny. Volba knihoven je na vás.
# 2. Představte jednotlivé příznaky pomocí textových popisů.
# 3. Analyzujte dataset pomocí popisných statistik s využitím vhodných vizualizačních metod. Svá zjištění komentujte.
# 4. Vyšetřete chybějící hodnoty (včetně jejich reprezentace) a odlehlá pozorování. Opět využijte vizualizace, pokud je to možné a svá zjištění komentujte.
# 5. Proveďte všechny další úpravy, které jsou podle vás pro práci s vybraným datasetem nezbytné (např. konverze datových typů, odstranění duplicitních údajů, vytvoření nových příznaků, sjednocení reprezentace chybějících dat nebo jejich odstranění apod.). K úpravě datasetu se můžete v průběhu řešení úlohy vracet.
# 6. Připravte dataset tak, abyste na něm mohli natrénovat a vyhodnotit vybraný model (např. data vhodně rozdělte, pokud je to pro váš model a evaluaci nutné, rozdělení komentujte, nebo můžete využít křížovou validaci apod. -> znáte z BI-ML1).
#
# Z této části lze získat celkem 15 bodů.
#
# **⚙️Model:**
# V této části je vaším úkolem natrénovat model, který se pokusí vyřešit vaši úlohu. Zaměřte se především na vizualizaci jednotlivých kroků a výsledků, včetně komentářů. Kvalita modelu jako takového nebude hodnocena.
# 1. Pro svoji úlohu zvolte vhodný klasifikační/regresní model.
# 2. Zvolte si alespoň dva hyperparametry spolu s minimálně pěti hodnotami (zde může být i více, případně méně v závislosti na zvoleném hyperparametru), jejichž nejlepší kombinaci budete během trénování modelu hledat. Zvolené hyperparametry a jejich hodnoty popište.
# 3. Zvolte a popište ztrátovou funkci, pomocí které provedete vyhodnocení úspěšnosti modelu.
# 4. Daný model na datasetu natrénujte. Pokud to lze, model vizualizujte.
# 5. Vhodně vizualizujte a komentujte vliv jednotlivých kombinací hyperparamentrů na úspěšnost modelu. Uveďte nejlepší kombinaci.
# 6. Pokud to lze (!), vizualizujte rozhodovací hranici nejlepšího modelu pro vámi vybrané příznaky. Pokud to nelze, zdůvodněte, případně realizujte jinou viualizaci související s prezentací nejlepšího modelu.
# 7. Vhodně vizualizujte úspěšnost výsledného modelu - využijte alespoň dvě vizualizační metody.
#
# **Pro zájemce:** Pokud byste chtěli, můžete pro řešení úlohy použít modelů více a provést jejich srovnání (včetně ladění hyperparametrů a dalších kroků zmíněných výše).
#
# Z této části lze získat celkem 25 bodů.
#
# ### Bodové hodnocení
# Shrnutí bodů, které můžete nejvýše získat:
# - 10 bodů za průběžné komentáře a vizuální prezentaci postupu a výsledků,
# - 15 bodů za předzpracování a prezentaci dat,
# - 25 bodů za trénování a vyhodnocení modelu:
#
# Celkem lze za domácí úkol č. 3 získat maximálně 50 bodů (každý člen týmu nebo jednotlivec).

# %%
# importing libraries
import pandas as pd
import re
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib
import numpy as np
import seaborn as sns
import datetime
import itertools
import io
import chess.pgn
import chess

# %% [markdown]
# # <font color='orange'>Dataset presenting</font>
#
# We used a chess dataset from https://www.kaggle.com/datasets/datasnaek/chess?resource=download. It is a collection of about 20000 chess games on the lichess platform.

# %% [markdown]
# # <font color='orange'>Dataset loading and description</font>

# %%
df = pd.read_csv("games.csv")

# %%
#to see a first couple of entries
display(df.head())

#to see some basic information about the dataset
display(df.info())

#to see how many unique values for each column
display(df.nunique())

display(df.describe())
# Out:
#          id  rated    created_at  last_move_at  turns victory_status winner  \
# 0  TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1  l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign  black
# 2  mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate  white
# 3  kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate  white
# 4  9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate  white
#
#   increment_code       white_id  white_rating      black_id  black_rating  \
# 0           15+2       bourgris          1500          a-00          1191
# 1           5+10           a-00          1322     skinnerua          1261
# 2           5+10         ischia          1496          a-00          1500
# 3           20+0  daniamurashov          1439  adivanov2009          1454
# 4           30+3      nik221107          1523  adivanov2009          1469
#
# ...

# %%
fig, ax = plt.subplots(figsize=(12,0.2))

sns.rugplot(df['turns'],height=1)
ax.yaxis.set_visible(False)
plt.show()

# %% [markdown]
# ### Data fields
# * **id** - ID of the game
# * **rated** - Rated (T/F)
# * **created_at** - Start Time
# * **ast_move_at** - End Time
# * **turns** - Number of Turns
# * **victory_status** - Winner
# * **increment_code** - Time and Increment
# * **white_id** - White Player ID
# * **white_rating** - White Player Rating
# * **black_id** - Black Player ID
# * **black_rating** - Black Player Rating
# * **moves** - All Moves in Standard Chess Notation
# * **opening_eco** - Opening Eco (Standardised Code for any given opening, list here)
# * **opening_name** - Opening Name
# * **opening_ply** - Opening Ply (Number of moves in the opening phase)

# %% [markdown]
# **Data exploration outcomes**
# * It looks like there are no NaN values.
# * Not all games have a unique set of moves. Might be a good idea to look into duplicates.
# * There is a game with more than 300 moves.
#
# **NaN values**
# Since this is a dataset, that was a result of data that was generated from chess games that were automatically saved by a chess website, there are not problems with missing values, since the website provides everything.

# %% [markdown]
# # <font color='orange'>Data preprocessing</font>

# %%
#change column to category where it is appropriate
df = df.astype({"victory_status":"category", 
                "winner":"category", 
                "increment_code":"category", 
                "opening_eco":"category", 
                "opening_name":"category"})

# %%
#since these colums have lost their float precision in the csv, they are quite useless to us
df.drop(columns=['created_at','last_move_at'],inplace=True)

# %% [markdown]
# # <font color='orange'>New columns</font>

# %%
df['is_checkmate'] = np.where(df['victory_status'] == 'mate', True, False)

# %%
#create columns with last move column, row and piece, to extract checkmate data more easily
def parse_last_move(moves):
    pgn = io.StringIO(moves)
    game = chess.pgn.read_game(pgn)
    board = game.end().board()
    last_move = chess.square_name(board.peek().to_square)
    last_move_piece = str(board.piece_at(board.peek().to_square)).upper()
   
    return last_move_piece, last_move

# apply the function to the 'moves' column of the df
df['last_move_piece'],df['last_move'] = zip(*df['moves'].map(parse_last_move))

# %%
#extraction of taken chess pieces for each side 
def count_losses(board, piece, color):
        if piece == chess.QUEEN:
            piece_count = 1
        elif piece in (chess.ROOK, chess.BISHOP, chess.KNIGHT):
            piece_count = 2
        elif piece == chess.PAWN:
            piece_count = 8
        
        #substracts the beggining number of pieces and the current one
        capture_count = piece_count - chess.popcount(board.pieces_mask(piece, color))

        return capture_count if capture_count >= 0 else 0

def extract_taken(moves):
    pgn = io.StringIO(moves)
    game = chess.pgn.read_game(pgn)
    board = game.end().board()
    white_captured = list()
    black_captured = list()
    
    return ( count_losses(board,chess.PAWN,chess.WHITE),
    count_losses(board,chess.KNIGHT,chess.WHITE),
    count_losses(board,chess.BISHOP,chess.WHITE),
    count_losses(board,chess.ROOK,chess.WHITE),
    count_losses(board,chess.QUEEN,chess.WHITE),
    count_losses(board,chess.PAWN,chess.BLACK),
    count_losses(board,chess.KNIGHT,chess.BLACK),
    count_losses(board,chess.BISHOP,chess.BLACK),
    count_losses(board,chess.ROOK,chess.BLACK),
    count_losses(board,chess.QUEEN,chess.BLACK) )
    

df['white_pawns_lost'],df['white_knights_lost'],df['white_bishops_lost'],df['white_rooks_lost'],df['white_queens_lost'],df['black_pawns_lost'],df['black_knights_lost'],df['black_bishops_lost'],df['black_rooks_lost'],df['black_queens_lost'] = zip(*df['moves'].map(extract_taken))

# %%
# extracts what side the game was played on more
def playside(moves):
    pgn = io.StringIO(moves)
    game = chess.pgn.read_game(pgn)
    board = game.board()
    moves, moves_on_white = 0 , 0
    for move in game.mainline_moves():
        moves+=1
        move_to=chess.square_name(move.to_square)
        #checks the move side and add one if it is white
        if int(move_to[1]) < 5:
            moves_on_white+=1
    return moves_on_white/moves

df['played_on_white_side'] = df['moves'].map(playside)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    20058 non-null  object
#  1   rated                 20058 non-null  bool
#  2   turns                 20058 non-null  int64
#  3   victory_status        20058 non-null  category
#  4   winner                20058 non-null  category
#  5   increment_code        20058 non-null  category
#  6   white_id              20058 non-null  object
#  7   white_rating          20058 non-null  int64
#  8   black_id              20058 non-null  object
#  9   black_rating          20058 non-null  int64
#  10  moves                 20058 non-null  object
#  11  opening_eco           20058 non-null  category
#  12  opening_name          20058 non-null  category
#  13  opening_ply           20058 non-null  int64
#  14  is_checkmate          20058 non-null  bool
# ...

# %% [markdown]
# Added some new columns, that may be useful for visualization or model training.

# %%
df.to_csv('games_preprocessed.csv', index=False)

# %% [markdown]
# # <font color='orange'>Visualization</font>

# %%
fig, ax = plt.subplots(1,2,figsize=(12,5))

#split last move into column and row
last_move_df = df.copy()

#only relevatn data
last_move_df = last_move_df[last_move_df.is_checkmate]

#split last move into row and column
last_move_df['last_move_row'] = last_move_df['last_move'].str[0]
last_move_df['last_move_col'] = last_move_df['last_move'].str[1]

# create a pivot table with the checkmate moves
pivot_table = last_move_df.pivot_table(values='last_move_piece', index='last_move_col', columns='last_move_row', aggfunc='count', dropna=True)
# create a heatmap using the pivot table
sns.heatmap(pivot_table, cmap='YlGnBu',ax=ax[0])
#for a proper view
ax[0].invert_yaxis()

bars = sns.countplot(x=last_move_df['last_move_piece'],ax=ax[1],order = last_move_df['last_move_piece'].value_counts().index,palette='YlGnBu')
labels=["Queen","Rook","Bishop","Knight","Pawn","King"]
ax[1].set_xticklabels(labels)

ax[0].set_xlabel(None)
ax[0].set_ylabel(None)
ax[1].set_xlabel(None)

ax[1].spines['top'].set_visible(False)
ax[1].spines['right'].set_visible(False)
ax[1].spines['left'].set_visible(False)
ax[1].yaxis.set_visible(False)

ax[1].bar_label(ax[1].containers[0])


ax[0].set_title("Heatmap of Checkmate moves on the chess board")
ax[1].set_title("Number of checkmates based on the piece that delivered it")
plt.show()

# %% [markdown]
# The kings may be a bit confusing, since you cannot give a check with a king. But in the three cases the king have moved out of the way of another figure, that checkmates the other player. So technically it was not the king that delivered it, but it was its move nontheless.

# %%
fig, ax = plt.subplots(figsize=(12,5))

# reate a new column in the df for the rating difference
df['rating_difference'] = df['white_rating'] - df['black_rating']

#create the plot
sns.kdeplot(y=df['rating_difference'],x=df['turns'],ax=ax,levels=10,color='powderblue',thresh=0.002)

plt.xlabel('Number of turns')
plt.ylabel('Rating difference')
ax.set_title('Number of turns based on the rating differnece')

plt.show()

# %% [markdown]
# Here we can see that in general, longer games only really occured when there were small differences in rating, which is something we would probably assume. SHorter games were more random

# %%
fig, ax = plt.subplots(figsize=(5,5))

values = df["victory_status"].value_counts()
labels = df["victory_status"].unique()
colors = ['powderblue', '#7b9fa1', '#e6b0d6', '#e6dcb0']
#explode makes the values more separate
ax.pie( values ,labels=labels, colors=colors ,explode=[0.02 for x in labels],autopct='%1.2f%%',pctdistance=0.85)

ax.set_title("The distribution of finish status")

#donut instead of bar chart
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()

fig.gca().add_artist(centre_circle)

plt.show()

# %% [markdown]
# Work continues in "model.ipynb" file.
